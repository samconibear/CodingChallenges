# %%
import sys
from UsefulPackages import install
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('worldometer_data.csv')

population = df.loc[:,'Population']
cases = df.loc[:,'TotalCases']
deaths = df.loc[:,'TotalDeaths']
tests = df.loc[:,'TotalTests']
deaths1m = df.loc[:,'Deaths/1M pop']
tests1m = df.loc[:,'Tests/1M pop']
deaths_per_pop = np.array(deaths) / np.array(population)
tests_per_pop = np.array(tests) / np.array(population)



#df['SelectionCondition']

plt.scatter(tests_per_pop, deaths_per_pop, s=1)
plt.show()

# %%
sample = np.random.randn(10000000)
sample.sort()
#y = np.ones(1000)
#sample = np.where(sample >= -1, sample, None)
#sample = [x for x in sample if x is not None]

plt.hist(sample, bins=10000)
plt.show()
